# %% [markdown]
# # Part II - (Ford GoBike System Dataset)
# ## by (Ziyad Almunyif)

# %% [markdown]
# ## Investigation Overview
#
# The goals of investigation Ford GoBike System Dataset is to see factors that affect Duration of a ride, and what gender uses bikes more, and Age of bikers affect Duration, and the amount of user Subscribed to the system.
#
#
#
#
#
# ## Dataset Overview
#
#
# The dataset includes information about individual rides made in a bike-sharing system covering San Francisco Bay area, it includes Age, duration, user type and gender columns, it have nearly 180k rows.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df = pd.read_csv('GoBike.csv')

# %% [markdown]
# > Note that the above cells have been set as "Skip"-type slides. That means
# that when the notebook is rendered as http slides, those cells won't show up.

# %% [markdown]
# ## What is The perecentage of Age of Biker
#
# The Age of biker that 41 to 141 years old is 23.2%, and The Age of bikers that 18 to 40 years old is 76.8%, it shows that older people still likes to Ride a bike since its nearly quarter of younger Age.

# %%
Above40 = df.query('Age >= 40')
below40 = df.query('Age < 40')
labels = '41-141','18-40'
size = [Above40.count()[0],below40.count()[0]]
titlee = 'Age of Bikers'
colors = ['#e65587','#55e6b4']
fig1, ax1 = plt.subplots()
ax1.pie(size, labels=labels, explode = (0, 0.1),shadow=True, autopct='%1.1f%%', startangle=90,colors=colors)
ax1.axis('equal')
plt.title(titlee)
plt.legend(["From 41 to 141","From 18 to 40"])
plt.show()

# %% [markdown]
# ##  Is there any relation between Gender and User Type
# as shown Male have super high count of subscibers compare to the rest, Most of the users that uses GoBike system is subscribed and few are just customer.

# %%
sb.countplot(data = df, x = 'member_gender', hue = 'user_type').set_title('Count of Gender that is Subscribed or a Customer');

# %% [markdown]
# ## Is there any relation between Age and Duration
#
# There is a strong relationship between the Age of Bike rider and Duration of the ride, when the Age decreases the Duration increases and the opposite is true meaning that Younger the rider Age is the longer time the ride will be.

# %%
bins_y = np.arange(18,7.5+141,7.5)
bins_x = np.arange(1,1409+75,75)
bins = [bins_x,bins_y]
plt.hist2d(data = df, y = 'Age', x = 'duration_minute', cmin=0.1 ,  cmap='viridis_r', bins = [bins_x, bins_y]);
plt.colorbar()
plt.gca().invert_yaxis()
plt.xlabel('Duration (minutes)')
plt.ylabel('Age')
plt.title('Trip Duration compare to Age')
# Out:
# Text(0.5,1,'Trip Duration compare to Age')

# %% [markdown]
# ### Generate Slideshow
# Once you're ready to generate your slideshow, use the `jupyter nbconvert` command to generate the HTML slide show.

# %%
# Use this command if you are running this file in local
# !jupyter nbconvert Part_II_slide_deck_template.ipynb --to slides --post serve --no-input --no-prompt
